# %% [markdown]
# # Shipping EDA
#
# This notebook is a lightweight exploration entry point for the shipping dashboard dataset.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/sample_shipping_data.csv')
df.head()

# %%
df.groupby('port_name')[['cargo_teu', 'turnaround_hours', 'avg_speed_knots']].mean().round(2)
